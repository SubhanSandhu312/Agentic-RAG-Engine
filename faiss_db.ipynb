# %%
import faiss

index = faiss.IndexFlatL2(384)  # Example: 128-dimensional vectors

# %%
from embeddings import embeddings_list

# %%
import numpy as np

# %%
embedding_array = np.array(embeddings_list, dtype="float32")

print(embedding_array.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 embedding_array = np.array(embeddings_list, dtype="float32")
#       2
#       3 print(embedding_array.shape)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (24, 3) + inhomogeneous part.

# %%
print(type(embeddings_list[0]))
print(len(embeddings_list[0]))
print(type(embeddings_list[0][0]))
# Out:
# <class 'tuple'>
# 3
# <class 'pathlib.WindowsPath'>

# %%
# index.add(embeddings_list)
index.add(np.array(embeddings_list).astype('float32'))  # Ensure embeddings are float32
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 # index.add(embeddings_list)
# ----> 2 index.add(np.array(embeddings_list).astype('float32'))  # Ensure embeddings are float32
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (24, 3) + inhomogeneous part.
